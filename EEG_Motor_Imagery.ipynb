# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/eeg-motor-imagery
# Out:
# /content/drive/MyDrive/eeg-motor-imagery

# %%
# !ls
# Out:
# app  data  README.md  requirements.txt	src

# %%
# !ls data/processed
# Out:
# all_subjects.pkl  subject_03.pkl  subject_06.pkl  subject_09.pkl
# subject_01.pkl	  subject_04.pkl  subject_07.pkl
# subject_02.pkl	  subject_05.pkl  subject_08.pkl

# %%
# !ls src
# Out:
# download_data.py  model.py  preprocess.py  train.py

# %%
# !pip install numpy scipy scikit-learn matplotlib mne torch torchvision tqdm
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 95.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: decorator
#     Found existing installation: decorator 4.4.2
#     Uninstalling decorator-4.4.2:
#       Successfully uninstalled decorator-4.4.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# moviepy 1.0.3 requires decorator<5.0,>=4.0.2, but you have decorator 5.2.1 which is incompatible.
# ...

# %%
import torch

print("CUDA available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# CUDA available: True
# GPU: Tesla T4

# %%
DATA_PATH = "data/processed/all_subjects.pkl"
CHECKPOINT_DIR = "checkpoints"

# %%
# %cd /content/drive/MyDrive/eeg-motor-imagery
# Out:
# /content/drive/MyDrive/eeg-motor-imagery

# %%
# !pwd
# !ls
# !ls src
# !ls data/processed
# Out:
# /content/drive/MyDrive/eeg-motor-imagery
# app  data  README.md  requirements.txt	src
# download_data.py  model.py  preprocess.py  train.py
# all_subjects.pkl  subject_03.pkl  subject_06.pkl  subject_09.pkl
# subject_01.pkl	  subject_04.pkl  subject_07.pkl
# subject_02.pkl	  subject_05.pkl  subject_08.pkl

# %%
# !grep "import EEGNet" src/train.py
# Out:
# from model import EEGNet, ShallowConvNet

# %%
# !python src/train.py
# Out:
# Device: cuda
# Loaded: (606, 64, 641) | 2 classes | 9 subjects
# LOSO CV: training 9 folds...
#
# ── Fold 1/9 | Test subject: 01 ──
#   Epoch  25/150 | train_acc 0.780 | test_acc 0.576 | kappa 0.220
#   Epoch  50/150 | train_acc 0.837 | test_acc 0.561 | kappa 0.260
#   Epoch  75/150 | train_acc 0.872 | test_acc 0.712 | kappa 0.454
#   Epoch 100/150 | train_acc 0.900 | test_acc 0.758 | kappa 0.526
#   Epoch 125/150 | train_acc 0.928 | test_acc 0.712 | kappa 0.454
#   Epoch 150/150 | train_acc 0.887 | test_acc 0.712 | kappa 0.454
#   Best → acc 0.803 | kappa 0.515
#
# ── Fold 2/9 | Test subject: 02 ──
#   Epoch  25/150 | train_acc 0.762 | test_acc 0.754 | kappa 0.378
#   Epoch  50/150 | train_acc 0.853 | test_acc 0.783 | kappa 0.506
#   Epoch  75/150 | train_acc 0.903 | test_acc 0.812 | kappa 0.589
#   Epoch 100/150 | train_acc 0.886 | test_acc 0.783 | kappa 0.534
#   Epoch 125/150 | train_acc 0.907 | test_acc 0.797 | kappa 0.561
# ...

# %%
# !ls checkpoints
# Out:
# fold_01.pt  fold_03.pt	fold_05.pt  fold_07.pt	fold_09.pt
# fold_02.pt  fold_04.pt	fold_06.pt  fold_08.pt	results_summary.pkl
